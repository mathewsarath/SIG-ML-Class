# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
D=pd.read_csv('1.01. Simple linear regression.csv')
plt.scatter(D.SAT,D.GPA)

# %%
LinearRegression().fit(D[['SAT']],D.GPA)
# Out:
# LinearRegression()

# %%
plt.scatter(D.SAT,D.GPA)
plt.plot(D.SAT,mdl.predict(D[['SAT']]),color='green')
